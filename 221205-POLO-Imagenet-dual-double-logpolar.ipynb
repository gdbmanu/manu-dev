# %% [markdown]
# # Loading Modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
from LogGabor import LogGabor
from what_where.main import init, MNIST
from what_where.where import RetinaFill, WhereShift, RetinaBackground, RetinaMask
from POLO.PYramid2 import cropped_pyramid, local_filter, get_K, log_gabor_transform
from POLO.PYramid2 import inverse_pyramid, get_K_inv, inverse_gabor
from utils import view_data
from typing import List, Tuple
# Out:
# Default lg shape= 32 32

# %%
#args.offset_std = 30
#args.contrast = 0.7

width = {'in': 32, 'out': 64}

n_levels = {'in': 3, 'out': 3} 

base_levels = 2

n_color = {'in': 3, 'out': 3}

color = True

color_mode= 'rgb' #'lab' # 'hsv' #True

r_min = {'in': width['in'] / 4, 'out': width['out'] / 4}

r_max = {'in': width['in'] / 2, 'out': width['out'] / 2}

n_sublevel = n_eccentricity = {'in': 2, 'out': 4}

n_azimuth = {'in': 16, 'out': 32}

n_theta = {'in': 8, 'out': 8}

n_phase = {'in': 1, 'out': 1}

do_mask = False

gauss = False

# %%
lg={}
for k in ['in', 'out']:
    pe = {'N_X': width[k], 'N_Y': width[k], 'do_mask': do_mask, 'base_levels':
              base_levels, 'n_theta': 0, 'B_sf': np.inf, 'B_theta': np.inf ,
          'use_cache': True, 'figpath': 'results', 'edgefigpath':
              'results/edges', 'matpath': 'cache_dir', 'edgematpath':
              'cache_dir/edges', 'datapath': 'database/', 'ext': '.pdf', 'figsize':
              14.0, 'formats': ['pdf', 'png', 'jpg'], 'dpi': 450, 'verbose': 0}   

    lg[k] = LogGabor(pe)

# %%
K = {}
for k in ['in', 'out']:
    K[k] = get_K(width=width[k],
          n_sublevel = n_sublevel[k], 
          n_azimuth = n_azimuth[k], 
          n_theta = n_theta[k],
          n_phase = n_phase[k], 
          r_min = r_min[k], 
          r_max = r_max[k], 
          log_density_ratio = 2, 
          verbose=True,
          lg=lg[k])
# Out:
# i_sublevel, sf_0, radius 0 0.36067376022224085 8.0
# i_sublevel, sf_0, radius 1 0.25503486164919736 11.31370849898476
# K shape= torch.Size([32, 32, 2, 16, 8, 1])
# K min max= tensor(-0.3125) tensor(1.)
# i_sublevel, sf_0, radius 0 0.18033688011112042 16.0
# i_sublevel, sf_0, radius 1 0.15164463602348005 19.027313840043536
# i_sublevel, sf_0, radius 2 0.12751743082459868 22.62741699796952
# i_sublevel, sf_0, radius 3 0.10722895046276856 26.908685288118864
# K shape= torch.Size([64, 64, 4, 32, 8, 1])
# K min max= tensor(-0.2759) tensor(1.)

# %%
K_inv={}
for k in ['in', 'out']:
    K_inv[k] = get_K_inv(K[k], 
                  width=width[k], 
                  n_sublevel = n_sublevel[k], 
                  n_azimuth = n_azimuth[k], 
                  n_theta = n_theta[k], 
                  n_phase = n_phase[k])
# Out:
# Filter tensor shape= torch.Size([32, 32, 2, 16, 8, 1])
# Reshaped filter tensor= torch.Size([1024, 256])
# Tensor shape= torch.Size([256, 1024])
# Filter tensor shape= torch.Size([64, 64, 4, 32, 8, 1])
# Reshaped filter tensor= torch.Size([4096, 1024])
# Tensor shape= torch.Size([1024, 4096])

# %% [markdown]
# # Loading the Data

# %% [markdown]
# - Loading the data with the parameters given in the .json file for the What/Where model

# %%
args = init(filename='2020-07-01')
args
# Out:
# {'w': 28,
#  'minibatch_size': 100,
#  'train_batch_size': 50000,
#  'test_batch_size': 10000,
#  'noise_batch_size': 1000,
#  'mean': 0.1307,
#  'std': 0.3081,
#  'what_offset_std': 15,
#  'what_offset_max': 25,
#  'N_pic': 128,
#  'offset_std': 30,
#  'offset_max': 34,
#  'noise': 0.75,
#  'contrast': 0.7,
#  'sf_0': 0.1,
#  'B_sf': 0.1,
#  'do_mask': True,
#  'N_theta': 6,
#  'N_azimuth': 24,
#  'N_eccentricity': 10,
#  'N_phase': 2,
#  'rho': 1.41,
#  'bias_deconv': True,
#  'p_dropout': 0.0,
#  'dim1': 1000,
#  'dim2': 1000,
#  'lr': 0.005,
#  'do_adam': True,
#  'bn1_bn_momentum': 0.5,
#  'bn2_bn_momentum': 0.5,
#  'momentum': 0.3,
#  'epochs': 60,
#  'num_processes': 1,
#  'no_cuda': False,
#  'log_interval': 100,
#  'verbose': 1,
#  'filename': '../data/2020-07-01',
#  'seed': 2019,
#  'N_cv': 10,
#  'do_compute': True,
#  'save_model': True}

# %%
class DualCroppedPyramid(object):
    def __init__(self, width, 
                 base_levels, 
                 color=color, 
                 do_mask=do_mask, 
                 verbose=False, 
                 n_levels=None, 
                 color_mode='rgb'):
        self.width = width
        self.base_levels = base_levels
        self.color = color
        self.do_mask = do_mask
        self.verbose = verbose
        self.n_levels = n_levels
        self.color_mode = color_mode

    def __call__(self, img):
        img_crop = {}
        for k in ['in', 'out']:
            img_crop_part, level_size = cropped_pyramid(img.unsqueeze(0), 
                                               width=self.width[k], 
                                               base_levels=self.base_levels,
                                               color=self.color, 
                                               do_mask=self.do_mask, 
                                               verbose=self.verbose,
                                               squeeze=True,
                                               gauss=gauss,
                                               n_levels=self.n_levels[k],
                                               color_mode=self.color_mode)
            #print(img_crop_part.shape)
            img_crop[k] = img_crop_part[:self.n_levels[k]-1,...]
        return img, img_crop

# %% [markdown]
# ### LogGaborTransform

# %%
class DualLogGaborTransform(object):
    def __init__(self, K=K, color=color, verbose=False):
        self.K = K
        self.color = color
        self.verbose = verbose

    def __call__(self, cropped_pyr):
        img = cropped_pyr[0]
        img_crop = cropped_pyr[1]
        log_gabor_coeffs = {}
        for k in ['in', 'out']:
            log_gabor_coeffs[k] = log_gabor_transform(img_crop[k].unsqueeze(1), K[k], color=self.color).squeeze(1)
        
        return img, log_gabor_coeffs

# %%
class DualLogGaborReshape(object):
    def __init__(self, n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color, verbose=False):
        self.n_levels = n_levels
        self.n_color = n_color
        self.n_eccentricity = n_eccentricity 
        self.n_azimuth = n_azimuth 
        self.n_theta = n_theta
        self.n_phase = n_phase  
        self.color = color
        self.verbose = verbose

    def __call__(self, log_gabor_transform):
        img = log_gabor_transform[0]
        log_gabor_coeffs = log_gabor_transform[1]
        for k in ['in', 'out']:
            # n_batch, n_levels, n_color, n_sublevel, n_azimuth, n_theta, n_phase
            # x      , 0       , 1      , 2         , 3        , 4      , 5
            # 
            #print(log_gabor_coeffs[k].shape)
            log_gabor_coeffs[k] = log_gabor_coeffs[k].permute(1, 4, 5, 0, 2, 3).contiguous()
            log_gabor_coeffs[k] = log_gabor_coeffs[k].view(self.n_color[k]*self.n_theta[k]*self.n_phase[k], 
                                                     (self.n_levels[k]-1) * self.n_eccentricity[k], 
                                                     self.n_azimuth[k])
 
        return img, log_gabor_coeffs

# %%
class LogGaborInvReshape(object):
    def __init__(self, n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color, verbose=False):
        self.n_levels = n_levels
        self.n_color = n_color
        self.n_eccentricity = n_eccentricity 
        self.n_azimuth = n_azimuth 
        self.n_theta = n_theta
        self.n_phase = n_phase  
        self.color = color
        self.verbose = verbose
    
    def __call__(self, log_gabor_coeffs):

        if self.verbose:
            print('log_gabor_coeffs.shape:', log_gabor_coeffs.shape)
        log_gabor_coeffs = log_gabor_coeffs.view(-1, 
                                                 self.n_color, 
                                                 self.n_theta, 
                                                 self.n_phase, 
                                                 self.n_levels, 
                                                 self.n_eccentricity, 
                                                 self.n_azimuth)
        log_gabor_coeffs = log_gabor_coeffs.permute(0, 4, 1, 5, 6, 2, 3).contiguous()
        return log_gabor_coeffs

# %%
class LogGaborInvTransform(object):
    def __init__(self, K_inv=K_inv, color=color, verbose=False):
        self.K_inv = K_inv
        self.color = color
        self.verbose = verbose
    
    def __call__(self, log_gabor_coeffs):
        img_crop=inverse_gabor(log_gabor_coeffs[:, :, 0, ...].detach(), self.K_inv, self.verbose)
        if self.verbose:
            print('img_crop.shape:', img_crop.shape)

        return img_crop

# %%
class InvCroppedPyramid(object):
    def __init__(self, 
                 #width, 
                 base_levels, 
                 color=color, 
                 #do_mask=do_mask, 
                 verbose=False, 
                 n_levels=None, 
                 color_mode='rgb',
                 N_X = 128,
                 N_Y = 128):
        #self.width = width
        self.base_levels = base_levels
        self.color = color
        #self.do_mask = do_mask
        self.verbose = verbose
        self.n_levels = n_levels
        self.color_mode = color_mode
        self.N_X = N_X
        self.N_Y = N_Y

    def __call__(self, img_crop):
        full_img_rec = inverse_pyramid(img_crop, 
                                       N_X = self.N_X,
                                       N_Y = self.N_Y,
                                       #width=self.width, 
                                       base_levels=self.base_levels,
                                       color=self.color, 
                                       #do_mask=self.do_mask, 
                                       verbose=self.verbose,
                                       #squeeze=True,
                                       gauss=gauss,
                                       n_levels=self.n_levels) #,
                                       #color_mode=self.color_mode)
        return full_img_rec

# %% [markdown]
# ### Inverse transformations (for display only)

# %% [markdown]
# # Exploring the MNIST with where noise parameters and log polar encoding

# %% [markdown]
# - 128x128 pixel with shift, noise and circular mask

# %%
#args.offset_max = 40 #like in the paper

# %%
# normalization used to train VGG
# see https://pytorch.org/hub/pytorch_vision_vgg/
v_mean = np.array([0.485, 0.456, 0.406])
v_std = np.array([0.229, 0.224, 0.225])
transforms_norm = transforms.Normalize(mean=v_mean, std=v_std) # to normalize colors on the imagenet dataset

# %%
image_size = 256

transform_big =  transforms.Compose([
            transforms.Resize((int(image_size), int(image_size))),
            #transforms.AutoAugment(), # https://pytorch.org/vision/master/transforms.html#torchvision.transforms.AutoAugment
            transforms.ToTensor(),      # Convert the image to pyTorch Tensor data type.
            #transforms_norm, 
            DualCroppedPyramid(width=width, 
                  base_levels=base_levels,
                  color=color,
                  n_levels=n_levels),
            DualLogGaborTransform(K=K, color=color),
            DualLogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color),
        ])

# %%
width,base_levels, color, n_levels
# Out:
# ({'in': 32, 'out': 64}, 2, True, {'in': 3, 'out': 3})

# %%
image_path = "../data/animal/"

image_dataset = { 'train' : datasets.ImageFolder(
                            image_path+'train', 
                            transform=transform_big
                        ),
                  'test' : datasets.ImageFolder(
                            image_path+'test', 
                            transform=transform_big
                        )
                }

# %%
dataset_size = {'train' : len(image_dataset['train']),
                'test' : len(image_dataset['test'])}

dataset_size['train'], dataset_size['test']
# Out:
# (2000, 1200)

# %%
batch_size = 50
num_workers = 1

dataloader = { 'train' : torch.utils.data.DataLoader(
                            image_dataset['train'], batch_size=batch_size,
                            shuffle=True, 
                            num_workers=num_workers,
                        ),
               'test' : torch.utils.data.DataLoader(
                            image_dataset['test'], batch_size=batch_size,
                            shuffle=True, 
                            num_workers=num_workers,
                        )
             }

# %%
data, label = next(iter(dataloader['train']))

# %%
data_original = data[0]
data_polo = data[1]
data_original.shape, data_polo['in'].shape, data_polo['out'].shape
# Out:
# (torch.Size([50, 3, 256, 256]),
#  torch.Size([50, 24, 4, 16]),
#  torch.Size([50, 24, 8, 32]))

# %%
# n_batch, n_levels, n_color, n_sublevel, n_azimuth, n_theta, n_phase

# %%
plt.plot(data_polo['in'][3,...].detach().numpy().flatten())
plt.plot(data_polo['out'][3,...].detach().numpy().flatten())

# %% [markdown]
# ### Displaying Log Gabor Encoded visual field using pseudo-inverse transformation

# %%
inverse_transform = {}
for k in ['in', 'out']:
    N_X = N_Y = width[k] * 2**(n_levels[k]-1)
    print(N_X)
    inverse_transform[k] = transforms.Compose([
        LogGaborInvReshape(n_levels[k], n_color[k], n_eccentricity[k], n_azimuth[k], n_theta[k], n_phase[k], color=color, verbose=False),        
        LogGaborInvTransform(K_inv=K_inv[k], color=color, verbose=False),
        InvCroppedPyramid(base_levels, n_levels=n_levels[k], verbose=False, N_X=N_X, N_Y=N_Y),
    ])
# Out:
# 128
# 256

# %% [markdown]
# - The Log-Polar compressed format

# %%
original = view_data(data_original, label, 5)

# %%
inverse_transform['in']
# Out:
# Compose(
#     <__main__.LogGaborInvReshape object at 0x7fc6e0912898>
#     <__main__.LogGaborInvTransform object at 0x7fc6e09128d0>
#     <__main__.InvCroppedPyramid object at 0x7fc6e0912908>
# )

# %% [raw]
# b = {'in':32,'out':64}
# for k in ['in', 'out']:
#     data = torch.cat((data_polo[k],torch.zeros_like(data_polo[k][:,:1,...])), dim=1)
#     full_img_rec = inverse_transform[k](data)
#     img_aff = full_img_rec[:,:,b[k]:-b[k],b[k]:-b[k]]
#     _ = view_data(img_aff, label, 5)
#     if k == 'in':
#         img_sum = full_img_rec
#     else:
#         img_sum += img_aff
# _ = view_data(img_sum, label, 5)

# %% [markdown]
# - The original format

# %%
data_polo['in'].shape, data_polo['out'].shape
# Out:
# (torch.Size([50, 24, 4, 16]), torch.Size([50, 24, 8, 32]))

# %% [markdown]
# # Creating an Attention Transformer model with log-polar entry (POLO-STN)

# %%
transform_in =  transforms.Compose([
            DualCroppedPyramid(width=width, 
                  base_levels=base_levels,
                  color=color,
                  n_levels=n_levels),
            DualLogGaborTransform(K=K, color=color),
            DualLogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color),
        ])

# %%
class Polo_AttentionTransNet(nn.Module):
    
    def __init__(self):
        super(Polo_AttentionTransNet, self).__init__()

        ##  The what pathway
        self.wloc1 = nn.Conv2d(n_color['out'] * n_theta['out'] * n_phase['out'], 
                              50, 3, padding=1)
        self.wloc2a = nn.Conv2d(50, 100, 3, padding=1)
        self.wloc2b = nn.Conv2d(n_color['in'] * n_theta['in'] * n_phase['in'], 
                               50, 3, padding=1)
        self.wloc3 = nn.Linear((n_levels['in']-1) * n_eccentricity['in'] // 2 * n_azimuth['in'] // 2 * (50+100), 
                              500)
        self.wloc4 = nn.Linear(500, 2)

        #self.wloc4.weight.data.zero_()
        #self.wloc4.bias.data.zero_()

                
        ##  The where pathway        
        self.loc1 = nn.Conv2d(n_color['out'] * n_theta['out'] * n_phase['out'], 
                              50, 3, padding=1)
        self.loc2a = nn.Conv2d(50, 100, 3, padding=1)
        self.loc2b = nn.Conv2d(n_color['in'] * n_theta['in'] * n_phase['in'], 
                               50, 3, padding=1)
        self.loc3 = nn.Linear((n_levels['in']-1) * n_eccentricity['in'] // 2 * n_azimuth['in'] // 2 * (50+100), 
                              500)
        self.loc4 = nn.Linear(500, 2)

        #self.loc4.weight.data.zero_()
        #self.loc4.bias.data.zero_()

        self.downscale = nn.Parameter(torch.tensor([[.5, 0], [0, .5]],
                                                   dtype=torch.float),
                                      requires_grad=False)

    def stn(self: object, x: torch.Tensor, x_polo: torch.Tensor) -> Tuple[torch.Tensor]:
    
        xs_part = {}
        #for k in ['in', 'out']:
        #    print(x_polo[k].shape)
        #    xs_part[k] = x_polo[k].permute(0,2,5,6,1,3,4)
        #    xs_part[k] = xs_part[k].view(-1, n_color[k] * n_theta[k] * n_phase[k], 
        #                                 (n_levels[k]-1) * n_eccentricity[k], 
        #                                 n_azimuth[k])
        
        #print(x_polo['out'].shape)
        
        xs = F.relu(self.loc1(x_polo['out']))
        xs = nn.MaxPool2d(2)(xs)        
        
        #print(xs.shape)
        
        xsa = F.relu(self.loc2a(xs))
        xsa = nn.MaxPool2d(2)(xsa)
        
        #print(xsa.shape)
        
        xsb = F.relu(self.loc2b(x_polo['in']))
        xsb = nn.MaxPool2d(2)(xsb)
        
        #print(xsb.shape)

        xs = torch.cat((xsa, xsb), dim=1)
        xs = F.relu(self.loc3(xs.view(-1, (50+100) * (n_levels['in']-1) * n_eccentricity['in'] // 2 * n_azimuth['in'] // 2)))
        theta = self.loc4(xs)

        theta = torch.cat((self.downscale.unsqueeze(0).repeat(
            theta.size(0), 1, 1), theta.unsqueeze(2)),
                          dim=2)
        
        #theta = theta.view(-1, 2, 3)
        
        grid_size = torch.Size([x.size()[0], x.size()[1], 128, 128])
        grid = F.affine_grid(theta, grid_size)
        x = F.grid_sample(x, grid)

        return x, theta

    def forward(self, x, x_polo):
        # transform the input
        x, _ = self.stn(x, x_polo)
        
        w_x_polo ={'in': torch.zeros_like(x_polo['in']),
                   'out': torch.zeros_like(x_polo['out'])}
        
        for i in range(batch_size):
            d, w = transform_in(x[i,...])
            w_x_polo['in'][i,...] = w['in']
            w_x_polo['out'][i,...] = w['out']
                                           

        # print(x.shape)
        # Perform the usual forward pass
        x = F.relu(self.wloc1(w_x_polo['out']))
        x = nn.MaxPool2d(2)(x)        
        
        #print(xs.shape)
        
        xa = F.relu(self.wloc2a(x))
        xa = nn.MaxPool2d(2)(xa)
        
        #print(xsa.shape)
        
        xb = F.relu(self.wloc2b(w_x_polo['in']))
        xb = nn.MaxPool2d(2)(xb)
        
        #print(xsb.shape)

        x = torch.cat((xa, xb), dim=1)
        x = F.relu(self.wloc3(x.view(-1, (50+100) * (n_levels['in']-1) * n_eccentricity['in'] // 2 * n_azimuth['in'] // 2)))
        x = self.wloc4(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#model = torch.load("../models/low_comp_polo_stn.pt")
model = Polo_AttentionTransNet().to(device)

# %%
def train(epoch, loader):
    model.train()
    for batch_idx, (data, target) in enumerate(loader):

        data_original, data_polo = data[0], data[1]
        data_original, data_polo['in'], data_polo['out'], target = data_original.to(
            device, dtype=torch.double), data_polo['in'].to(
                device, dtype=torch.double), data_polo['out'].to(
                device, dtype=torch.double), target.to(device)

        optimizer.zero_grad()
        output = model(data_original, data_polo)
        loss = loss_func(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {}/{} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, args.epochs, batch_idx * len(data_original),
                len(dataloader['train'].dataset),
                100. * batch_idx / len(dataloader['train']), loss.item()))


def test(loader):
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in loader:
            data_original, data_polo = data[0], data[1]
            data_original = data_original.to(device, dtype=torch.double)            
            data_polo['in'] = data_polo['in'].to(device, dtype=torch.double) 
            data_polo['out'] = data_polo['out'].to(device, dtype=torch.double) 
            target = target.to(device)

            output = model(data_original, data_polo)

            # sum up batch loss
            #test_loss += F.nll_loss(output, target, size_average=False).item()
            test_loss += loss_func(output, target).item()
            # get the index of the max log-probability
            #pred = output.max(1, keepdim=True)[1]
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(dataloader['test'].dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, len(dataloader['test'].dataset),
                     100. * correct / len(dataloader['test'].dataset)))
        return correct / len(dataloader['test'].dataset)

# %% [markdown]
# # Training

# %%
lr = 1e-3

# %%
optimizer = optim.Adam(model.parameters(), lr=lr)
loss_func = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9, last_epoch=-1) #, verbose=True)

# %%
acc = []

# %%
args.epochs = 100

for epoch in range(1, args.epochs + 1):
    train(epoch, dataloader['train'])
    curr_acc = test(dataloader['test'])
    acc.append(curr_acc)
    scheduler.step()
# Out:
# Train Epoch: 1/100 [0/2000 (0%)]	Loss: 0.695325
#
# Test set: Average loss: 0.0138, Accuracy: 665/1200 (55%)
#
# Train Epoch: 2/100 [0/2000 (0%)]	Loss: 0.689801
#
# Test set: Average loss: 0.0134, Accuracy: 715/1200 (60%)
#
# Train Epoch: 3/100 [0/2000 (0%)]	Loss: 0.668075
#
# Test set: Average loss: 0.0130, Accuracy: 758/1200 (63%)
#
# Train Epoch: 4/100 [0/2000 (0%)]	Loss: 0.632065
#
# Test set: Average loss: 0.0127, Accuracy: 787/1200 (66%)
#
# Train Epoch: 5/100 [0/2000 (0%)]	Loss: 0.551780
#
# Test set: Average loss: 0.0126, Accuracy: 812/1200 (68%)
#
# Train Epoch: 6/100 [0/2000 (0%)]	Loss: 0.575122
#
# Test set: Average loss: 0.0121, Accuracy: 836/1200 (70%)
#
# Train Epoch: 7/100 [0/2000 (0%)]	Loss: 0.601448
#
# Test set: Average loss: 0.0124, Accuracy: 797/1200 (66%)
#
# Train Epoch: 8/100 [0/2000 (0%)]	Loss: 0.648163
#
# Test set: Average loss: 0.0120, Accuracy: 805/1200 (67%)
#
# Train Epoch: 9/100 [0/2000 (0%)]	Loss: 0.515813
#
# Test set: Average loss: 0.0118, Accuracy: 817/1200 (68%)
#
# Train Epoch: 10/100 [0/2000 (0%)]	Loss: 0.518249
#
# Test set: Average loss: 0.0120, Accuracy: 828/1200 (69%)
#
# Train Epoch: 11/100 [0/2000 (0%)]	Loss: 0.508750
#
# Test set: Average loss: 0.0125, Accuracy: 804/1200 (67%)
#
# Train Epoch: 12/100 [0/2000 (0%)]	Loss: 0.507534
#
# Test set: Average loss: 0.0126, Accuracy: 816/1200 (68%)
#
# Train Epoch: 13/100 [0/2000 (0%)]	Loss: 0.540928
#
# Test set: Average loss: 0.0139, Accuracy: 679/1200 (57%)
#
# Train Epoch: 14/100 [0/2000 (0%)]	Loss: 0.748445
#
# Test set: Average loss: 0.0138, Accuracy: 609/1200 (51%)
#
# Train Epoch: 15/100 [0/2000 (0%)]	Loss: 0.687088
#
# Test set: Average loss: 0.0138, Accuracy: 607/1200 (51%)
#
# Train Epoch: 16/100 [0/2000 (0%)]	Loss: 0.695258
#
# Test set: Average loss: 0.0139, Accuracy: 606/1200 (50%)
#
# Train Epoch: 17/100 [0/2000 (0%)]	Loss: 0.689151
#
# Test set: Average loss: 0.0139, Accuracy: 602/1200 (50%)
#
# Train Epoch: 18/100 [0/2000 (0%)]	Loss: 0.695537
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 19/100 [0/2000 (0%)]	Loss: 0.693351
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 20/100 [0/2000 (0%)]	Loss: 0.691963
#
# Test set: Average loss: 0.0139, Accuracy: 596/1200 (50%)
#
# Train Epoch: 21/100 [0/2000 (0%)]	Loss: 0.693066
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 22/100 [0/2000 (0%)]	Loss: 0.693051
#
# Test set: Average loss: 0.0139, Accuracy: 603/1200 (50%)
#
# Train Epoch: 23/100 [0/2000 (0%)]	Loss: 0.692933
#
# Test set: Average loss: 0.0138, Accuracy: 603/1200 (50%)
#
# Train Epoch: 24/100 [0/2000 (0%)]	Loss: 0.683318
#
# Test set: Average loss: 0.0138, Accuracy: 610/1200 (51%)
#
# Train Epoch: 25/100 [0/2000 (0%)]	Loss: 0.692603
#
# Test set: Average loss: 0.0138, Accuracy: 603/1200 (50%)
#
# Train Epoch: 26/100 [0/2000 (0%)]	Loss: 0.667776
#
# Test set: Average loss: 0.0138, Accuracy: 619/1200 (52%)
#
# Train Epoch: 27/100 [0/2000 (0%)]	Loss: 0.682285
#
# Test set: Average loss: 0.0136, Accuracy: 667/1200 (56%)
#
# Train Epoch: 28/100 [0/2000 (0%)]	Loss: 0.698867
#
# Test set: Average loss: 0.0138, Accuracy: 649/1200 (54%)
#
# Train Epoch: 29/100 [0/2000 (0%)]	Loss: 0.670416
#
# Test set: Average loss: 0.0139, Accuracy: 596/1200 (50%)
#
# Train Epoch: 30/100 [0/2000 (0%)]	Loss: 0.705690
#
# Test set: Average loss: 0.0139, Accuracy: 606/1200 (50%)
#
# Train Epoch: 31/100 [0/2000 (0%)]	Loss: 0.693785
#
# Test set: Average loss: 0.0139, Accuracy: 607/1200 (51%)
#
# Train Epoch: 32/100 [0/2000 (0%)]	Loss: 0.693210
#
# Test set: Average loss: 0.0139, Accuracy: 599/1200 (50%)
#
# Train Epoch: 33/100 [0/2000 (0%)]	Loss: 0.692522
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 34/100 [0/2000 (0%)]	Loss: 0.693451
#
# Test set: Average loss: 0.0139, Accuracy: 602/1200 (50%)
#
# Train Epoch: 35/100 [0/2000 (0%)]	Loss: 0.690953
#
# Test set: Average loss: 0.0139, Accuracy: 603/1200 (50%)
#
# Train Epoch: 36/100 [0/2000 (0%)]	Loss: 0.687175
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 37/100 [0/2000 (0%)]	Loss: 0.692620
#
# Test set: Average loss: 0.0139, Accuracy: 603/1200 (50%)
#
# Train Epoch: 38/100 [0/2000 (0%)]	Loss: 0.693113
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 39/100 [0/2000 (0%)]	Loss: 0.687231
#
# Test set: Average loss: 0.0139, Accuracy: 603/1200 (50%)
#
# Train Epoch: 40/100 [0/2000 (0%)]	Loss: 0.693586
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 41/100 [0/2000 (0%)]	Loss: 0.692986
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 42/100 [0/2000 (0%)]	Loss: 0.693753
#
# Test set: Average loss: 0.0139, Accuracy: 603/1200 (50%)
#
# Train Epoch: 43/100 [0/2000 (0%)]	Loss: 0.693313
#
# Test set: Average loss: 0.0138, Accuracy: 603/1200 (50%)
#
# Train Epoch: 44/100 [0/2000 (0%)]	Loss: 0.692989
#
# Test set: Average loss: 0.0138, Accuracy: 603/1200 (50%)
#
# Train Epoch: 45/100 [0/2000 (0%)]	Loss: 0.691902
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 46/100 [0/2000 (0%)]	Loss: 0.693351
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 47/100 [0/2000 (0%)]	Loss: 0.693269
#
# Test set: Average loss: 0.0139, Accuracy: 601/1200 (50%)
#
# Train Epoch: 48/100 [0/2000 (0%)]	Loss: 0.694969
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 49/100 [0/2000 (0%)]	Loss: 0.693163
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 50/100 [0/2000 (0%)]	Loss: 0.693153
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 51/100 [0/2000 (0%)]	Loss: 0.693125
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 52/100 [0/2000 (0%)]	Loss: 0.693334
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 53/100 [0/2000 (0%)]	Loss: 0.692457
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 54/100 [0/2000 (0%)]	Loss: 0.692874
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 55/100 [0/2000 (0%)]	Loss: 0.693221
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 56/100 [0/2000 (0%)]	Loss: 0.692507
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 57/100 [0/2000 (0%)]	Loss: 0.692579
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 58/100 [0/2000 (0%)]	Loss: 0.693149
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 59/100 [0/2000 (0%)]	Loss: 0.693152
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 60/100 [0/2000 (0%)]	Loss: 0.693807
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 61/100 [0/2000 (0%)]	Loss: 0.693013
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 62/100 [0/2000 (0%)]	Loss: 0.693134
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 63/100 [0/2000 (0%)]	Loss: 0.692956
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 64/100 [0/2000 (0%)]	Loss: 0.692567
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 65/100 [0/2000 (0%)]	Loss: 0.692871
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 66/100 [0/2000 (0%)]	Loss: 0.693022
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 67/100 [0/2000 (0%)]	Loss: 0.693530
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 68/100 [0/2000 (0%)]	Loss: 0.692848
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 69/100 [0/2000 (0%)]	Loss: 0.693469
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 70/100 [0/2000 (0%)]	Loss: 0.693911
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 71/100 [0/2000 (0%)]	Loss: 0.693330
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 72/100 [0/2000 (0%)]	Loss: 0.693704
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 73/100 [0/2000 (0%)]	Loss: 0.693042
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 74/100 [0/2000 (0%)]	Loss: 0.692227
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 75/100 [0/2000 (0%)]	Loss: 0.693202
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 76/100 [0/2000 (0%)]	Loss: 0.693102
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
# Train Epoch: 77/100 [0/2000 (0%)]	Loss: 0.693147
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 78/100 [0/2000 (0%)]	Loss: 0.693033
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 79/100 [0/2000 (0%)]	Loss: 0.693219
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 80/100 [0/2000 (0%)]	Loss: 0.693056
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 81/100 [0/2000 (0%)]	Loss: 0.693356
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 82/100 [0/2000 (0%)]	Loss: 0.694070
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 83/100 [0/2000 (0%)]	Loss: 0.692837
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 84/100 [0/2000 (0%)]	Loss: 0.693143
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 85/100 [0/2000 (0%)]	Loss: 0.693149
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 86/100 [0/2000 (0%)]	Loss: 0.693294
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 87/100 [0/2000 (0%)]	Loss: 0.693225
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 88/100 [0/2000 (0%)]	Loss: 0.693431
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 89/100 [0/2000 (0%)]	Loss: 0.693480
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 90/100 [0/2000 (0%)]	Loss: 0.693197
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 91/100 [0/2000 (0%)]	Loss: 0.692659
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 92/100 [0/2000 (0%)]	Loss: 0.693243
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 93/100 [0/2000 (0%)]	Loss: 0.693149
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 94/100 [0/2000 (0%)]	Loss: 0.693842
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 95/100 [0/2000 (0%)]	Loss: 0.693190
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 96/100 [0/2000 (0%)]	Loss: 0.693066
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 97/100 [0/2000 (0%)]	Loss: 0.692923
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 98/100 [0/2000 (0%)]	Loss: 0.693116
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 99/100 [0/2000 (0%)]	Loss: 0.693439
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)
#
# Train Epoch: 100/100 [0/2000 (0%)]	Loss: 0.693528
#
# Test set: Average loss: 0.0139, Accuracy: 600/1200 (50%)

# %%
curr_acc = test(dataloader['test'])

# %%
torch.save(model, "low_comp_polo_stn_dual.pt")

# %%
data, label = next(iter(dataloader['train']))

# %%
transform_in(data[0][0,...])
# Out:
# (tensor([[[0.6392, 0.6549, 0.6627,  ..., 0.0784, 0.0745, 0.0667],
#           [0.6510, 0.6588, 0.6627,  ..., 0.0745, 0.0706, 0.0627],
#           [0.6549, 0.6588, 0.6667,  ..., 0.0745, 0.0745, 0.0706],
#           ...,
#           [0.3922, 0.3961, 0.4039,  ..., 0.0471, 0.0431, 0.0392],
#           [0.3961, 0.3882, 0.3922,  ..., 0.0431, 0.0431, 0.0431],
#           [0.4039, 0.3882, 0.3922,  ..., 0.0431, 0.0431, 0.0431]],
#
#          [[0.6549, 0.6667, 0.6745,  ..., 0.0784, 0.0745, 0.0706],
#           [0.6588, 0.6706, 0.6824,  ..., 0.0784, 0.0824, 0.0784],
#           [0.6588, 0.6745, 0.6863,  ..., 0.0824, 0.0784, 0.0784],
#           ...,
#           [0.3647, 0.3647, 0.3725,  ..., 0.0471, 0.0510, 0.0471],
#           [0.3608, 0.3569, 0.3608,  ..., 0.0510, 0.0510, 0.0510],
#           [0.3647, 0.3569, 0.3529,  ..., 0.0510, 0.0510, 0.0510]],
#
#          [[0.6588, 0.6706, 0.6784,  ..., 0.0863, 0.0784, 0.0784],
#           [0.6627, 0.6745, 0.6824,  ..., 0.0863, 0.0784, 0.0784],
#           [0.6627, 0.6784, 0.6863,  ..., 0.0784, 0.0784, 0.0784],
#           ...,
#           [0.3176, 0.3294, 0.3373,  ..., 0.0471, 0.0392, 0.0392],
#           [0.3098, 0.3137, 0.3176,  ..., 0.0471, 0.0431, 0.0471],
#           [0.3059, 0.3059, 0.3098,  ..., 0.0471, 0.0471, 0.0471]]]),
#  {'in': tensor([[[ 3.9863e-03, -6.1101e-03, -5.2410e-03,  ...,  3.9108e-03,
#             -4.6143e-03,  1.8260e-02],
#            [ 2.2824e-02, -1.0042e-02,  2.4670e-04,  ..., -2.7577e-02,
#             -6.6565e-03, -3.3141e-03],
#            [-4.8196e-02,  4.5057e-03, -1.6632e-03,  ...,  3.6358e-02,
#              5.9444e-02,  4.7719e-02],
#            [-1.2445e-02,  7.2085e-02,  5.3879e-02,  ...,  3.9315e-02,
#              2.7924e-02, -2.8875e-02]],
#
#           [[-2.1436e-02, -2.2097e-02, -2.9142e-02,  ...,  1.1482e-04,
#             -1.3455e-02,  3.0925e-02],
#            [-1.7630e-03, -3.4322e-02,  3.3066e-02,  ...,  3.7359e-03,
#             -7.7817e-03,  2.2043e-03],
#            [-1.0816e-02,  5.2943e-02, -9.0700e-02,  ...,  4.9284e-02,
#              5.5576e-02, -3.6613e-02],
#            [ 3.7339e-02,  9.2977e-02, -5.5317e-02,  ...,  5.7495e-02,
#             -6.0944e-02, -2.0085e-02]],
#
#           [[-8.4738e-03, -8.0448e-03, -4.1345e-02,  ..., -1.5576e-02,
#             -1.3603e-02,  1.4462e-02],
#            [ 1.3498e-02, -7.3347e-03,  2.2231e-02,  ...,  1.8051e-02,
#             -1.0612e-02,  4.4551e-03],
#            [ 1.3163e-02,  2.8212e-03, -3.2684e-02,  ...,  4.6404e-02,
#             -1.0778e-02, -1.3822e-02],
#            [-5.8599e-02,  6.1189e-02, -8.4678e-02,  ...,  6.9026e-04,
#             -5.6718e-02,  2.9552e-02]],
#
#           ...,
#
#           [[-1.9170e-02,  8.7987e-03,  9.4884e-03,  ..., -3.9865e-02,
#              3.1649e-02,  5.0176e-02],
#            [-1.3133e-01, -5.2704e-02,  2.8904e-02,  ..., -1.0178e-02,
#              4.0648e-02,  1.0109e-01],
#            [ 9.2672e-02,  4.7885e-02, -9.6991e-02,  ...,  7.9303e-03,
#              3.4351e-02,  2.0770e-01],
#            [ 9.0158e-02,  1.6261e-01, -2.3058e-02,  ...,  1.3342e-02,
#              8.8101e-02,  1.8680e-01]],
#
#           [[-2.6818e-03, -3.8737e-02,  6.0803e-02,  ..., -1.6263e-02,
#              2.7700e-02,  1.2469e-01],
#            [ 3.8091e-02, -2.2435e-02, -3.0504e-03,  ...,  4.2276e-02,
#              5.5741e-02,  5.0696e-02],
#            [ 1.4268e-01,  9.7409e-04, -1.1618e-01,  ...,  4.6743e-02,
#              1.6447e-01,  2.9137e-02],
#            [ 1.0795e-01,  1.0718e-02, -1.6609e-01,  ...,  2.1835e-01,
#              1.6987e-01, -1.4627e-02]],
#
#           [[ 1.4110e-02, -2.8634e-02,  4.2624e-02,  ...,  1.6149e-02,
#             -1.8500e-02,  6.2515e-02],
#            [ 1.9067e-02, -3.3669e-02, -5.2514e-02,  ...,  3.6665e-02,
#              3.4054e-02, -6.0714e-04],
#            [ 2.4412e-02, -1.6359e-01,  7.4258e-03,  ...,  1.5976e-01,
#              6.5578e-02,  5.6530e-02],
#            [-6.4954e-02, -9.7852e-02, -1.7730e-01,  ...,  3.0092e-01,
#              5.7353e-02, -1.1904e-02]]]),
#   'out': tensor([[[-0.0087, -0.0048,  0.0008,  ...,  0.0354,  0.0372,  0.0132],
#            [-0.0287, -0.0355, -0.0532,  ...,  0.0201,  0.0092, -0.0272],
#            [-0.0200, -0.0003,  0.0238,  ...,  0.0270, -0.0029, -0.0150],
#            ...,
#            [-0.0604, -0.0210, -0.0108,  ...,  0.0418,  0.0290, -0.0296],
#            [ 0.0309,  0.0334,  0.0169,  ...,  0.0033,  0.0120,  0.0090],
#            [-0.0130,  0.0092, -0.0114,  ..., -0.2356, -0.1319, -0.0336]],
#
#           [[-0.0052,  0.0166,  0.0114,  ...,  0.0447, -0.0049,  0.0056],
#            [ 0.0094,  0.0063,  0.0065,  ..., -0.0101, -0.0270, -0.0167],
#            [-0.0098,  0.0303,  0.0306,  ..., -0.0183, -0.0264, -0.0239],
#            ...,
#            [-0.0286,  0.0173,  0.0019,  ...,  0.0031,  0.0212, -0.0760],
#            [ 0.0196,  0.0297, -0.0107,  ..., -0.0251, -0.0090, -0.0094],
#            [-0.0150, -0.0180, -0.0164,  ..., -0.1069, -0.0739,  0.0072]],
#
#           [[ 0.0149,  0.0177, -0.0154,  ...,  0.0128, -0.0293,  0.0123],
#            [ 0.0523, -0.0272,  0.0843,  ..., -0.0155, -0.0144,  0.0205],
#            [ 0.0005, -0.0197, -0.0003,  ..., -0.0313, -0.0186, -0.0063],
#            ...,
#            [ 0.0888,  0.0343, -0.0008,  ..., -0.0624,  0.0430, -0.1359],
#            [ 0.0642,  0.0264,  0.0119,  ..., -0.0493, -0.0042, -0.0732],
#            [ 0.0025,  0.0125,  0.0263,  ..., -0.0138, -0.0039,  0.0150]],
#
#           ...,
#
#           [[ 0.0455,  0.0537, -0.0831,  ...,  0.0793,  0.1097,  0.0403],
#            [ 0.0607,  0.0449,  0.0107,  ...,  0.0467,  0.1405, -0.0188],
#            [-0.0126,  0.0599, -0.0251,  ...,  0.0524,  0.1105,  0.1091],
#            ...,
#            [ 0.0795,  0.0714,  0.0196,  ...,  0.0952,  0.0712,  0.1376],
#            [ 0.0752,  0.0419,  0.0378,  ..., -0.0074,  0.0457, -0.0167],
#            [ 0.0439,  0.0449,  0.0436,  ..., -0.0782,  0.0628, -0.0074]],
#
#           [[ 0.0675,  0.0585, -0.0644,  ...,  0.0728, -0.0162, -0.0065],
#            [ 0.0770,  0.0341, -0.0710,  ..., -0.0025,  0.0090, -0.0288],
#            [-0.0085,  0.0558,  0.0036,  ...,  0.0948,  0.0679, -0.0051],
#            ...,
#            [ 0.0032, -0.0060,  0.0362,  ...,  0.0391, -0.1053, -0.0017],
#            [ 0.0151,  0.0119,  0.0044,  ..., -0.1524,  0.0458, -0.0657],
#            [ 0.0054,  0.0301,  0.0532,  ..., -0.1794,  0.0666,  0.0471]],
#
#           [[ 0.0052, -0.0453, -0.0521,  ...,  0.0279,  0.0233,  0.0416],
#            [ 0.0074, -0.0265, -0.1114,  ..., -0.0243,  0.0011, -0.0030],
#            [ 0.0089, -0.0287,  0.0031,  ...,  0.0450, -0.0316,  0.0054],
#            ...,
#            [-0.0117,  0.0018,  0.0399,  ...,  0.0150,  0.0205,  0.0155],
#            [ 0.0562,  0.0044, -0.0104,  ...,  0.1460,  0.1472,  0.0010],
#            [ 0.0147,  0.0470,  0.0257,  ..., -0.2093,  0.0309,  0.0643]]])})

# %%
output = model.stn(data[0], data[1])

# %%
output[0].shape
# Out:
# torch.Size([50, 3, 128, 128])

# %%
img.size()[1]
# Out:
# 3

# %%
#theta = torch.cat((model.downscale.unsqueeze(0).repeat(
#            theta.size(0), 1, 1), theta.unsqueeze(2)),
#                          dim=2)
        
        #theta = theta.view(-1, 2, 3)
num = 1
img = data[0][:1,...]   
theta = output[1][:1,...]
theta[0,:,2] = torch.FloatTensor((0,.5))
print(theta)
grid_size = torch.Size([1, 3, 128, 128])
grid = F.affine_grid(theta, grid_size)
img_grid = F.grid_sample(img, grid)
plt.imshow(img_grid[0,:].permute(1,2,0).detach().numpy())
# Out:
# tensor([[[0.5000, 0.0000, 0.0000],
#          [0.0000, 0.5000, 0.5000]]], grad_fn=<AsStridedBackward0>)

# %%
plt.imshow(data[0][1,:].permute(1,2,0).detach().numpy())

# %%
plt.imshow(output[0][1,:].permute(1,2,0).detach().numpy())

# %%
output[1][1][:,2].detach().numpy()
# Out:
# array([12.96344633, -0.29534955])

# %% [markdown]
# # Training on lesser contrasts

# %%
#optimizer = optim.SGD(model.parameters(), lr=lr) #
#loss_func = nn.CrossEntropyLoss()
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5, last_epoch=-1)

# %%
for contrast in (0.5, 0.3):

    print("training on contrast %s" %(contrast))

    args.offset_std = 40 #train while the maximum range is 40
    args.contrast = contrast
    transform_big = transforms.Compose([
        RetinaFill(N_pic=args.N_pic),
        WhereShift(args),
        RetinaBackground(contrast=args.contrast,
                         noise=args.noise,
                         sf_0=args.sf_0,
                         B_sf=args.B_sf, flexible=True),
        RetinaMask(N_pic=args.N_pic),
        transforms.ToTensor(),
        DualCroppedPyramid(width, 
                       base_levels, 
                       n_levels=n_levels),
        DualLogGaborTransform(color=color),
        #LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color)
    ])


    train_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=True,
        download=True,
        transform=transform_big,
    ),
                                               batch_size=args.minibatch_size,
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=False,
        download=True,
        transform=transform_big,
    ),
                                              batch_size=args.minibatch_size,
                                              shuffle=True)

    print("Training on eccentricity=%s" % (args.offset_std))
    args.epochs = 40

    for epoch in range(1, args.epochs + 1):
        train(epoch, train_loader)
        curr_acc = test(test_loader)
        #acc.append(curr_acc)
        scheduler.step()
    torch.save(model, f"low_comp_polo_stn_{contrast}.pt")

# %% [markdown]
# ## Retraining with a fresh scheduler

# %%
optimizer = optim.SGD(model.parameters(), lr=lr) #
loss_func = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5, last_epoch=-1)

# %%
for contrast in (0.3,):

    print("training on contrast %s" %(contrast))

    args.offset_std = 40 #train while the maximum range is 40
    args.contrast = contrast
    transform_big = transforms.Compose([
        RetinaFill(N_pic=args.N_pic),
        WhereShift(args),
        RetinaBackground(contrast=args.contrast,
                         noise=args.noise,
                         sf_0=args.sf_0,
                         B_sf=args.B_sf, flexible=True),
        RetinaMask(N_pic=args.N_pic),
        transforms.ToTensor(),
        DualCroppedPyramid(width, 
                       base_levels, 
                       n_levels=n_levels),
        DualLogGaborTransform(color=color),
        #LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color)
    ])


    train_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=True,
        download=True,
        transform=transform_big,
    ),
                                               batch_size=args.minibatch_size,
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=False,
        download=True,
        transform=transform_big,
    ),
                                              batch_size=args.minibatch_size,
                                              shuffle=True)

    print("Training on eccentricity=%s" % (args.offset_std))
    args.epochs = 50

    for epoch in range(1, args.epochs + 1):
        train(epoch, train_loader)
        curr_acc = test(test_loader)
        #acc.append(curr_acc)
        scheduler.step()
    torch.save(model, f"low_comp_polo_stn_{contrast}_retrain.pt")

# %%
for contrast in (0.3,):

    print("training on contrast %s" %(contrast))

    args.offset_std = 40 #train while the maximum range is 40
    args.contrast = contrast
    transform_big = transforms.Compose([
        RetinaFill(N_pic=args.N_pic),
        WhereShift(args),
        RetinaBackground(contrast=args.contrast,
                         noise=args.noise,
                         sf_0=args.sf_0,
                         B_sf=args.B_sf, flexible=True),
        RetinaMask(N_pic=args.N_pic),
        transforms.ToTensor(),
        DualCroppedPyramid(width, 
                       base_levels, 
                       n_levels=n_levels),
        DualLogGaborTransform(color=color),
        #LogGaborReshape(n_levels, n_color, n_eccentricity, n_azimuth, n_theta, n_phase, color=color)
    ])


    train_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=True,
        download=True,
        transform=transform_big,
    ),
                                               batch_size=args.minibatch_size,
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(MNIST(
        '../data',
        train=False,
        download=True,
        transform=transform_big,
    ),
                                              batch_size=args.minibatch_size,
                                              shuffle=True)

    print("Training on eccentricity=%s" % (args.offset_std))
    args.epochs = 50

    for epoch in range(1, args.epochs + 1):
        train(epoch, train_loader)
        curr_acc = test(test_loader)
        #acc.append(curr_acc)
        scheduler.step()
    torch.save(model, f"low_comp_polo_stn_{contrast}_retrain_continued.pt")

# %% [markdown]
# # Saving the model

# %% [markdown]
# # Visualizing some transformations

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    #mean = np.array([0.485, 0.456, 0.406])
    #std = np.array([0.229, 0.224, 0.225])
    #inp = std * inp + mean
    #inp = np.clip(inp, 0, 1)
    return inp

thetas = []
def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        
        data, label = next(iter(test_loader))
        data_original = data[0][:16, ...].to(device)
        data_polo = {'in': data[1]['in'][:16, ...].to(device),
                     'out': data[1]['out'][:16, ...].to(device)}
        
        input_tensor = data_original.cpu()
        
        output_tensor, theta = model.stn(data_original, data_polo)
        thetas.append(theta)
        
        #output_tensor = F.pad(input=output_tensor, pad=(50, 50, 50, 50), mode='constant', value=0)

        transformed_input_tensor = output_tensor.cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor, nrow=4))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor, nrow=4))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2, dpi=300)
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')
        axarr[0].set_xticks([0, 131])
        axarr[0].set_yticks([390])
        axarr[0].set_yticklabels([128])
        axarr[0].set_xticklabels([0, 128])

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')
        axarr[1].set_xticks([0, 30])
        axarr[1].set_yticks([90])
        axarr[1].set_yticklabels([28])
        axarr[1].set_xticklabels([0, 28])

        #f.savefig('../figures/polo_atn_attention.png')

# %%
visualize_stn()

# %%
visualize_stn()

# %%
visualize_stn()

# %%
visualize_stn()

# %% [markdown]
# # Performance of the Polo-ATN

# %%
def test(loader):
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in loader:
            data_original, data_polo = data[0], data[1]
            data_original = data_original.to(device, dtype=torch.double)            
            data_polo['in'] = data_polo['in'].to(device, dtype=torch.double) 
            data_polo['out'] = data_polo['out'].to(device, dtype=torch.double) 
            target = target.to(device)

            output = model(data_original, data_polo)

            # sum up batch loss
            #test_loss += F.nll_loss(output, target, size_average=False).item()
            test_loss += loss_func(output, target).item()
            # get the index of the max log-probability
            #pred = output.max(1, keepdim=True)[1]
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, len(test_loader.dataset),
                     100. * correct / len(test_loader.dataset)))
        return correct / len(test_loader.dataset)

# %%
polo_atn_stats = {}

for contrast in contrasts:
    print("Testing on contrast = %s" % (contrast))

    accuracies = []

    for ecc in eccentricities:
        

        transform_big = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius=ecc),  # given eccentricity
            RetinaBackground(
                contrast=contrast,  # given contrast
                noise=args.noise,
                sf_0=args.sf_0,
                B_sf=args.B_sf,
                flexible=False),  # a fixed contrast
            RetinaMask(N_pic=args.N_pic),
            transforms.ToTensor(),
            DualCroppedPyramid(width, base_levels, n_levels=n_levels),
            DualLogGaborTransform(color=color),
            #DualLogGaborReshape(n_levels,
            #                n_color,
            #                n_eccentricity,
            #                n_azimuth,
            #                n_theta,
            #                n_phase,
            #                color=color)
        ])
        train_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=True,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)

        test_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=False,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)
        print("Testing on eccentricity = %s" % (ecc))
        acc = test(test_loader)
        accuracies.append(acc)

    polo_atn_stats[contrast] = np.array(accuracies)

# %%
polo_atn_stats = {}

for contrast in contrasts:
    print("Testing on contrast = %s" % (contrast))

    accuracies = []

    for ecc in eccentricities:
        

        transform_big = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius=ecc),  # given eccentricity
            RetinaBackground(
                contrast=contrast,  # given contrast
                noise=args.noise,
                sf_0=args.sf_0,
                B_sf=args.B_sf,
                flexible=False),  # a fixed contrast
            RetinaMask(N_pic=args.N_pic),
            transforms.ToTensor(),
            DualCroppedPyramid(width, base_levels, n_levels=n_levels),
            DualLogGaborTransform(color=color),
            #DualLogGaborReshape(n_levels,
            #                n_color,
            #                n_eccentricity,
            #                n_azimuth,
            #                n_theta,
            #                n_phase,
            #                color=color)
        ])
        train_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=True,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)

        test_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=False,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)
        print("Testing on eccentricity = %s" % (ecc))
        acc = test(test_loader)
        accuracies.append(acc)

    polo_atn_stats[contrast] = np.array(accuracies)

# %%
polo_atn_stats = {}

for contrast in contrasts:
    print("Testing on contrast = %s" % (contrast))

    accuracies = []

    for ecc in eccentricities:
        

        transform_big = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius=ecc),  # given eccentricity
            RetinaBackground(
                contrast=contrast,  # given contrast
                noise=args.noise,
                sf_0=args.sf_0,
                B_sf=args.B_sf,
                flexible=False),  # a fixed contrast
            RetinaMask(N_pic=args.N_pic),
            transforms.ToTensor(),
            DualCroppedPyramid(width, base_levels, n_levels=n_levels),
            DualLogGaborTransform(color=color),
            #DualLogGaborReshape(n_levels,
            #                n_color,
            #                n_eccentricity,
            #                n_azimuth,
            #                n_theta,
            #                n_phase,
            #                color=color)
        ])
        train_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=True,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)

        test_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=False,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)
        print("Testing on eccentricity = %s" % (ecc))
        acc = test(test_loader)
        accuracies.append(acc)

    polo_atn_stats[contrast] = np.array(accuracies)

# %%
polo_atn_stats = {}

for contrast in contrasts:
    print("Testing on contrast = %s" % (contrast))

    accuracies = []

    for ecc in eccentricities:
        

        transform_big = transforms.Compose([
            RetinaFill(N_pic=args.N_pic),
            WhereShift(args, radius=ecc),  # given eccentricity
            RetinaBackground(
                contrast=contrast,  # given contrast
                noise=args.noise,
                sf_0=args.sf_0,
                B_sf=args.B_sf,
                flexible=False),  # a fixed contrast
            RetinaMask(N_pic=args.N_pic),
            transforms.ToTensor(),
            DualCroppedPyramid(width, base_levels, n_levels=n_levels),
            DualLogGaborTransform(color=color),
            #DualLogGaborReshape(n_levels,
            #                n_color,
            #                n_eccentricity,
            #                n_azimuth,
            #                n_theta,
            #                n_phase,
            #                color=color)
        ])
        train_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=True,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)

        test_loader = torch.utils.data.DataLoader(
            MNIST(
                '../data',
                train=False,
                download=True,
                transform=transform_big,
            ),
            batch_size=args.minibatch_size,
            shuffle=True)
        print("Testing on eccentricity = %s" % (ecc))
        acc = test(test_loader)
        accuracies.append(acc)

    polo_atn_stats[contrast] = np.array(accuracies)

# %%
polo_atn_stats

# %%
polo_atn_stats

# %%
polo_atn_stats

# %%
### ref
accuracy_data= [0.62, 0.69, 0.726, 0.714, 0.799, 0.81, 0.846, 0.889, 0.89 ] 
accuracy_data = accuracy_data[::-1]

# %%
plt.plot(polo_atn_stats[0.7])
plt.plot(polo_atn_stats[0.5])
plt.plot(polo_atn_stats[0.3])
plt.plot(accuracy_data)

# %%
plt.plot(polo_atn_stats[0.7])
plt.plot(polo_atn_stats[0.5])
plt.plot(polo_atn_stats[0.3])
plt.plot(accuracy_data)

# %%
plt.plot(polo_atn_stats[0.7])
plt.plot(polo_atn_stats[0.5])
plt.plot(polo_atn_stats[0.3])
plt.plot(accuracy_data)

# %%
### Contrast 0.7 only

# %% [raw]
# {0.7: array([0.9314, 0.9246, 0.9155, 0.9055, 0.8891, 0.8567, 0.7999, 0.6687,
#         0.5278]),
#  0.5: array([0.7538, 0.7103, 0.6627, 0.6246, 0.6456, 0.5843, 0.4563, 0.3101,
#         0.2139]),
#  0.3: array([0.2362, 0.2145, 0.1777, 0.1526, 0.1465, 0.1331, 0.1222, 0.1147,
#         0.1124])}

# %%
### Training on 0.7, 0.5 and 0.3

# %% [raw]
# {0.7: array([0.9433, 0.9225, 0.9094, 0.8795, 0.8441, 0.8161, 0.7546, 0.6577,
#         0.5629]),
#  0.5: array([0.8412, 0.8191, 0.8149, 0.8075, 0.7947, 0.7254, 0.5903, 0.4263,
#         0.3093]),
#  0.3: array([0.4043, 0.3552, 0.3237, 0.3055, 0.3   , 0.2445, 0.1836, 0.1366,
#         0.1246])}

# %%
### 50 epochs retraining on 0.3

# %% [raw]
# {0.7: array([0.9454, 0.9309, 0.9282, 0.9134, 0.9033, 0.8701, 0.8148, 0.6628,
#         0.5667]),
#  0.5: array([0.8703, 0.8529, 0.8473, 0.8338, 0.8153, 0.7362, 0.5749, 0.3936,
#         0.2837]),
#  0.3: array([0.4791, 0.4221, 0.3846, 0.3482, 0.3153, 0.2465, 0.1738, 0.1299,
#         0.1194])}

# %%
### 100 epochs retraining on 0.3

# %% [raw]
# {0.7: array([0.9493, 0.9373, 0.9318, 0.9204, 0.9111, 0.8886, 0.832 , 0.6749,
#         0.5789]),
#  0.5: array([0.8764, 0.8544, 0.855 , 0.8395, 0.8202, 0.7456, 0.5869, 0.396 ,
#         0.2865]),
#  0.3: array([0.4882, 0.4286, 0.3916, 0.3536, 0.3222, 0.2466, 0.176 , 0.1289,
#         0.1176])}
